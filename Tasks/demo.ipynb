# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1= cv2.imread("Task 3.2img1.png")
img2 = cv2.imread("Task 3.2img2.png")

# %%
print(img1.shape)
print(img2.shape)
# Out:
# (228, 222, 3)
# (201, 195, 3)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img3= img1[0:100, 75:145]
img4= img2[15:145, 40:140]

# %%
plt.imshow(img3)

# %%
plt.imshow(img4)

# %%
img4= cv2.resize(img4,(70,100))
img3= cv2.resize(img3,(100,130))

# %%
plt.imshow(img3)

# %%
plt.imshow(img4)

# %%
img1[0:100, 75:145] = img4
img2[15:145, 40:140] = img3

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)
